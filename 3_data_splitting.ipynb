# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FOLDERNAME = 'Colab\ Notebooks'

# %cd drive/MyDrive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks

# %%
import os
import glob

import pandas as pd
from PIL import Image
from tqdm import tqdm
from tqdm import trange

# %%
data_root = "./Dataset"

files = glob.glob(os.path.join(data_root, "*/*.jpg"))
print(f"{len(files)} images")
# Out:
# 11243 images

# %%
df = []

for f in tqdm(files):
    cat = f.split('/')[-2]
    try: 
        img = Image.open(f)
        w, h = img.size

        df.append(
            dict(
                img_path=f,
                cat=cat,
                w=w,
                h=h,
                max_dim=max(w, h)
            )
        )
    except:
        continue
    
df = pd.DataFrame(df)
df
# Out:
# 100%|██████████| 11243/11243 [30:22<00:00,  6.17it/s]
#                                                 img_path  \
# 0      ./Dataset/Dracaena_trifasciata/resize_Dracaena...
# 1      ./Dataset/Dracaena_trifasciata/resize_Dracaena...
# 2      ./Dataset/Dracaena_trifasciata/resize_Dracaena...
# 3      ./Dataset/Dracaena_trifasciata/resize_Dracaena...
# 4      ./Dataset/Dracaena_trifasciata/resize_Dracaena...
# ...                                                  ...
# 11236  ./Dataset/Nephrolepis_cordifolia/2271155729_47...
# 11237  ./Dataset/Nephrolepis_cordifolia/23200175311_f...
# 11238  ./Dataset/Nephrolepis_cordifolia/2263518760_6f...
# 11239  ./Dataset/Nephrolepis_cordifolia/9049930900_be...
# 11240  ./Dataset/Nephrolepis_cordifolia/11746678233_1...
#
#                           cat     w     h  max_dim
# 0        Dracaena_trifasciata   767  1024     1024
# 1        Dracaena_trifasciata  1024   768     1024
# 2        Dracaena_trifasciata   768  1024     1024
# 3        Dracaena_trifasciata   682  1024     1024
# 4        Dracaena_trifasciata   768  1024     1024
# ...                       ...   ...   ...      ...
# 11236  Nephrolepis_cordifolia  1024   768     1024
# 11237  Nephrolepis_cordifolia  1024  1024     1024
# 11238  Nephrolepis_cordifolia  1024   768     1024
# 11239  Nephrolepis_cordifolia  1024   767     1024
# 11240  Nephrolepis_cordifolia  1024   768     1024
#
# [11241 rows x 5 columns]

# %%
val_frac = 0.05
test_frac = 0.05

df["subset"] = "train"
df.loc[df.query("subset == 'train'").sample(frac=val_frac).index, "subset"] = "val"
df.loc[df.query("subset == 'train'").sample(frac=val_frac).index, "subset"] = "test"
df.head()
# Out:
#                                             img_path                   cat  \
# 0  ./Dataset/Dracaena_trifasciata/resize_Dracaena...  Dracaena_trifasciata
# 1  ./Dataset/Dracaena_trifasciata/resize_Dracaena...  Dracaena_trifasciata
# 2  ./Dataset/Dracaena_trifasciata/resize_Dracaena...  Dracaena_trifasciata
# 3  ./Dataset/Dracaena_trifasciata/resize_Dracaena...  Dracaena_trifasciata
# 4  ./Dataset/Dracaena_trifasciata/resize_Dracaena...  Dracaena_trifasciata
#
#       w     h  max_dim subset
# 0   767  1024     1024   test
# 1  1024   768     1024  train
# 2   768  1024     1024  train
# 3   682  1024     1024  train
# 4   768  1024     1024  train

# %%
# df.to_csv('sample_lst.csv', index=False)

# %%
df = pd.read_csv('sample_lst.csv')

# %%
df['cat'].value_counts().reset_index().sort_values('cat', ascending=False)
# Out:
#                      index   cat
# 0             Hoya_carnosa  1295
# 1       Monstera_deliciosa   996
# 2          Asplenium_nidus   885
# 3     Tradescantia_zebrina   811
# 4              Zamioculcas   766
# 5        Epipremnum_aureum   728
# 6     Aglaonema_commutatum   669
# 7         Dypsis_lutescens   583
# 8           Rhapis_excelsa   513
# 9       Maranta_leuconeura   497
# 10   Schefflera_arboricola   458
# 11        Pachira_aquatica   452
# 12  Philodendron_gloriosum   375
# 13   Peperomia_obtusifolia   368
# 14        Dracaena_reflexa   366
# 15     Chamaedorea_elegans   363
# 16      Calathea_orbifolia   311
# 17    Dracaena_trifasciata   309
# 18      Peperomia_argyreia   284
# 19  Nephrolepis_cordifolia   212

# %%
pd.pivot_table(df, index='cat', columns='subset', values='img_path', aggfunc = 'count').sort_values('train', ascending=False)
# Out:
# subset                  test  train  val
# cat
# Hoya_carnosa              56   1157   82
# Monstera_deliciosa        44    906   46
# Asplenium_nidus           39    806   40
# Tradescantia_zebrina      35    733   43
# Zamioculcas               54    661   51
# Epipremnum_aureum         31    658   39
# Aglaonema_commutatum      27    605   37
# Dypsis_lutescens          22    541   20
# Rhapis_excelsa            22    463   28
# Maranta_leuconeura        31    444   22
# Pachira_aquatica          25    405   22
# Schefflera_arboricola     31    404   23
# Philodendron_gloriosum    16    342   17
# Chamaedorea_elegans       15    336   12
# Peperomia_obtusifolia     15    333   20
# Dracaena_reflexa          24    327   15
# Calathea_orbifolia        11    290   10
# Dracaena_trifasciata      15    280   14
# Peperomia_argyreia        11    262   11
# Nephrolepis_cordifolia    10    192   10

# %%
export_dst = "./Final_data"


for i in trange(len(df)):
    try: 
        image_path, cat, subset = df.iloc[i][["img_path", "cat", "subset"]]
        img = Image.open(image_path)
        w, h = img.size
        os.makedirs(os.path.join(export_dst, subset, cat), exist_ok=True)

        if w > h:
            w_dst = 1024
            h_dst = int(h / w * 1024)
        else:
            h_dst = 1024
            w_dst = int(w / h * 1024)


        img = img.resize((w_dst, h_dst), resample=Image.BILINEAR)
        img.save(os.path.join(export_dst, subset, cat, os.path.basename(image_path)))
        
        
    except:
        continue
# Out:
# 100%|██████████| 11241/11241 [16:33<00:00, 11.32it/s]
